# %%
# import gdown
# # https://drive.google.com/file/d/1Aw0Zx3wUtRm09-OdSjjLt5Ua01T8e_a3/view?usp=sharing
# url = 'https://drive.google.com/uc?id=1Aw0Zx3wUtRm09-OdSjjLt5Ua01T8e_a3'
# output = 'myDataSet.zip'
# gdown.download(url, output, quiet=False)

# !unzip /content/drive/MyDrive/yoloUseEEmy.zip -d /content

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11142, done.
# remote: Total 11142 (delta 0), reused 0 (delta 0), pack-reused 11142
# Receiving objects: 100% (11142/11142), 11.09 MiB | 31.29 MiB/s, done.
# Resolving deltas: 100% (7708/7708), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 6.2 MB/s

# %%
import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.4/166.8 GB disk)

# %% [markdown]
# ## dataset
# ├── images
# ├─── train ── allimagesTrain.jpg
# ├─── val ── allimagesVal.jpg
# ├── labels
# ├─── train ── allimagesTrain.jpg
# ├─── val ── allimagesVal.jpg
# ├─── allLabels.txt
#
# ## yourYaml.ymal
# path: ../datasets/coco  # dataset root dir
# train: images/train  # train images (relative to 'path')
# val: images/validations  # val images (relative to 'path')
# test: test-dev2017.txt  # (optional)
#
# ## Classes
# nc: 2  # number of classes
# names: ['person', 'bicycle']  # class names

# %%
# !python train.py --img 640 --batch 32 --epochs 80 --data /content/yoloUseEE/flow.ymal --weights yolov5s.pt --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=/content/yoloUseEE/flow.ymal, hyp=data/hyps/hyp.scratch-low.yaml, epochs=80, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data /content/myDataSet/flow.ymal --weights runs/train/exp/weights/best.pt --cache

# %%
# !zip -r /content/yolov5Train.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1646122543.c894c779c1b6.358.0 (deflated 44%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/exp/results.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 20%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/labels.jpg (deflated 19%)
#   adding: content/yolov5/runs/train/exp/train_batch2.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 41%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
# ...
